# %% [markdown]
# # Notebook 04 — Markov Rating Migration
#
# Eight-state transition matrix (A..G + Default absorbing state). Used as a TTC complement to the Vasicek PiT PD.

# %% [markdown]
# Transition matrix:
#
# |    |     A |     B |     C |     D |     E |     F |     G |     D |
# |:---|------:|------:|------:|------:|------:|------:|------:|------:|
# | A  | 0.36  | 0.099 | 0.099 | 0.099 | 0.099 | 0.099 | 0.099 | 0.046 |
# | B  | 0.174 | 0.316 | 0.087 | 0.087 | 0.087 | 0.087 | 0.087 | 0.076 |
# | C  | 0.152 | 0.152 | 0.276 | 0.076 | 0.076 | 0.076 | 0.076 | 0.115 |
# | D  | 0.135 | 0.135 | 0.135 | 0.245 | 0.067 | 0.067 | 0.067 | 0.147 |
# | E  | 0.123 | 0.123 | 0.123 | 0.123 | 0.224 | 0.062 | 0.062 | 0.158 |
# | F  | 0.11  | 0.11  | 0.11  | 0.11  | 0.11  | 0.201 | 0.055 | 0.193 |
# | G  | 0.105 | 0.105 | 0.105 | 0.105 | 0.105 | 0.105 | 0.19  | 0.181 |
# | D  | 0     | 0     | 0     | 0     | 0     | 0     | 0     | 1     |

# %% [markdown]
# - Source: **synthetic**
# - 5y lifetime PD for grade A: **0.4750**
# - 5y lifetime PD for grade G: **0.4238**

# %% [markdown]
# ![markov](../reports/figures/fig_notebook_04_markov.png)
