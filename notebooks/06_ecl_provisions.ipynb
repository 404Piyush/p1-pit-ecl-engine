# %% [markdown]
# # Notebook 06 — ECL Term Structure & Quarterly Reporting
#
# Per-loan ECL over eight Ind AS 109 reporting dates.

# %% [markdown]
# | reporting_date   |   n_loans |   n_stage1 |   n_stage2 |   n_stage3 |   ecl_total |   ecl_mean |
# |:-----------------|----------:|-----------:|-----------:|-----------:|------------:|-----------:|
# | Q1               |      5021 |       4500 |        217 |        304 | 4.69892e+06 |     935.85 |
# | Q2               |      5021 |       4500 |        217 |        304 | 5.18028e+06 |    1031.72 |
# | Q3               |      5021 |       4500 |        217 |        304 | 5.66397e+06 |    1128.06 |
# | Q4               |      5021 |       4500 |        217 |        304 | 6.15009e+06 |    1224.87 |
# | Q5               |      5021 |       4500 |        217 |        304 | 6.63874e+06 |    1322.19 |
# | Q6               |      5021 |       4500 |        217 |        304 | 7.13002e+06 |    1420.04 |
# | Q7               |      5021 |       4500 |        217 |        304 | 7.62405e+06 |    1518.43 |
# | Q8               |      5021 |       4500 |        217 |        304 | 8.12096e+06 |    1617.4  |

# %% [markdown]
# ![ECL trend](../reports/figures/fig_notebook_06_ecl_trend.png)

# %% [markdown]
# **Final reporting-date ECL total:** INR 8,120,964
