# %% [markdown]
# # Notebook 05 — SICR & Stage Assignment
#
# Statistically-staged ECL under baseline and adverse macro scenarios.

# %% [markdown]
# **Baseline**
# - Stage1 ECL: INR 1,995,849
# - Stage2 ECL: INR 489,510
# - Stage3 ECL: INR 729,808
#
# **Adverse**
# - Stage1 ECL: INR 3,876,289
# - Stage2 ECL: INR 933,366
# - Stage3 ECL: INR 1,391,549

# %% [markdown]
# ![staging](../reports/figures/fig_notebook_05_staging.png)

# %% [markdown]
# SICR threshold is the ratio of PiT lifetime PD to origination PD exceeding a static cutoff. Default (DPD>90) is always Stage 3.
