# %% [markdown]
# # Notebook 02 - Classification & Calibration
#
# Compares **Platt scaling** vs **isotonic regression** for the LightGBM 12-month-default classifier.

# %%
from src.classifier import compare_calibrators
import numpy as np

# %% [markdown]
# Selected calibrator: `platt`
#
# - AUC raw = 0.6059
# - AUC calibrated = 0.6059
# - Brier raw = 0.0920
# - Brier calibrated = 0.0923
# - Isotonic Brier = 0.0930
# - Isotonic AUC = 0.5769

# %% [markdown]
# ![classification](../reports/figures/fig_notebook_02_classification.png)
