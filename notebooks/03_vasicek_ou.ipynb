# %% [markdown]
# # Notebook 03 — Vasicek & Ornstein-Uhlenbeck
#
# Systematic credit factor `Z_t` extracted from the macro panel and mean-reversion dynamics under Euler-Maruyama.

# %% [markdown]
# - Vasicek rho = **0.0500**
# - TTC PD = **0.0500**
# - OU parameters: theta=3.1546  mu=-0.1720  sigma=1.6202

# %% [markdown]
# ![vasicek OU](../reports/figures/fig_notebook_03_vasicek_ou.png)

# %% [markdown]
# The Vasicek single-factor model isolates the systematic driver of default rates; the OU process propagates it forward under stressed macro scenarios.
